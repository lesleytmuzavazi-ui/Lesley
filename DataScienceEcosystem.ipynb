# %% [markdown]
# **Data Science Tools and Ecosystem**
#
# ---

# %% [markdown]
# Some of the popular languages that Data Scientists use are :
# 1. Python
# 2. R
# 3. SQL
# 4. C++
# 5. Java

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - ggplot2
# - scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Category | Tools |
# |---|---|
# | Data Management | MySQL, PostgreSQL, MongoDB |
# | Data Integration | Apache Airflow, Talend, Kafka |
# | Visualization | Tableau, Power BI, Matplotlib, ggplot2 |
# | Machine Learning | scikit-learn, TensorFlow, Keras |

# %% [markdown]
# Arithmetic Expression example.
#
# Below is a simple arithmetic expression.
#
# 1.  (20 + 5) * 4

# %% [markdown]
# ## Converting Minutes to Hours

# %% [markdown]
# # Convert minutes to hours (rounded to 2 decimals)
# minutes = 200
# hours = minutes / 60
# round(hours, 2)

# %% [markdown]
# ## Objectives
# - List popular languages for Data Science
# - Identify commonly used libraries
# - Create a table of Data Science tools
# - Demonstrate arithmetic operations
# - Convert units using simple code

# %% [markdown]
# ## Author
# Lesley Muzavazi
